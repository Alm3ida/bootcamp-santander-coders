# %%
numero = 66234000
num1 = 1            #1
num2 = 33413        #3
num3 = 1000000      #1.000.000
num4 = 123120318923 #123.120.318.923

def num_dec(num):
    num_nome = str(num)
    casas = len(num_nome) // 3
    new_num = []
    num_decimal = []
    for i in range(1, len(num_nome) + 1):
        if i % 3 == 0 and i != len(num_nome):
            new_num.append(num_nome[-i])
            new_num.append('.')
        else:
            new_num.append(num_nome[-i])
    x = ''.join(new_num[::-1])
    return x

print(num_dec(numero))
print(num_dec(num1))
print(num_dec(num2))
print(num_dec(num3))
print(num_dec(num4))
# Out:
# 66.234.000
# 1
# 33.413
# 1.000.000
# 123.120.318.923
