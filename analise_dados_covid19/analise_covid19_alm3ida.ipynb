# %% [markdown]
# # Análise de Dados Covid 19 🧫
#
# Esse projeto foi desenvolvido durante o bootcamp **Santander Coders - Ciência de Dados 2021**, onde é realizada a análise de dados relacionados a API pública de dados da Covid 19.
# <table>
#   <tr>
#     <td><img src="imagem_corona_virus.jpeg" alt="Figura Corona Virus" width="125"/>
#     <td><p> Os dados utilizados nesse projeto provém da API pública que pode ser encontrada <a href="https://api.covid19api.com/dayone/country/brazil">aqui</a><p>
#   </tr>
# </table>

# %%
# !pip install requests

# %% [markdown]
# ## Coletando os dados da API

# %%
import requests as r

# %%
url = 'https://api.covid19api.com/dayone/country/brazil'

with r.get(url) as file:
    raw_data = file.json()

# %%
# Status da API => 2XX == OK
file.status_code
# Out:
# 200

# %%
raw_data[0]
# Out:
# {'ID': '63aa488e-b4a2-4fcd-ae15-07c1ff219903',
#  'Country': 'Brazil',
#  'CountryCode': 'BR',
#  'Province': '',
#  'City': '',
#  'CityCode': '',
#  'Lat': '-14.24',
#  'Lon': '-51.93',
#  'Confirmed': 1,
#  'Deaths': 0,
#  'Recovered': 0,
#  'Active': 1,
#  'Date': '2020-02-26T00:00:00Z'}
